# %% [markdown]
# <a href="https://colab.research.google.com/github/aleenajaleel/attendence_report_analysis/blob/main/if_and_else_withlogics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.	Driving Eligibility
#  Write a Python program to input age and check:
# ○	If age is 18 or above and age is below 60 → "Eligible to Drive"
# ○	Otherwise → "Not Eligible"

# %%
age=int(input("Enter your age: "))
if age>=18 and age<60:
    print("Eligible to Drive")
else:
    print("Not Eligible")
# Out:
# Enter your age: 19
# Eligible to Drive

# %%
#2.	Number Check
 #Input a number and check whether it is:
#	Positive and even
#	Positive and odd
#	Negative
#	Zero

# %%
number=int(input("Enter a number: "))
if number>0 and number%2==0:
    print("Positive and even")
elif number>0 and number%2!=0:
    print("Positive and odd")
elif number<0:
    print("Negative")
# Out:
# Enter a number: 45
# Positive and odd

# %%
#3.	Voting Eligibility
#Input age and citizenship status ("Indian" or "Other").
#	If age is 18 or above and citizenship is Indian → "Eligible to Vote"
#	Otherwise → "Not Eligible"

# %%
age=int(input("Enter your age: "))
citizenship=input("Enter your citizenship: ")
if age>=18 and citizenship=="Indian":
    print("Eligible to Vote")
else:
    print("Not Eligible")
# Out:
# Enter your age: 34
# Enter your citizenship: Indian
# Eligible to Vote

# %%
#4.	Free Entry
#Input age and student status.
#	If age is below 12 or the person is a student → "Free Entry"
#	Otherwise → "Ticket Required"

# %%
age=int(input("enter your age: "))
student=input("enter your student status: ")
if age<12 or student=="student":
    print("Free Entry")
else:
    print("Ticket Required")
# Out:
# enter your age: 32
# enter your student status: student
# Free Entry

# %%
#5.	Temperature Alert
# Input temperature:
#	Above 40 → "Extreme Heat"
#	Between 30 and 40 → "Hot"
#	Between 20 and 29 → "Normal"
#	Below 20 → "Cold"

# %%
temperature=int(input("enter  temperature: "))
if temperature>40:
    print("Extreme Heat")
elif temperature>=30 and temperature<=40:
    print("Hot")
elif temperature>=20 and temperature<=29:
    print("Normal")
else:
    print("Cold")
# Out:
# enter  temperature: 56
# Extreme Heat

# %%
#6.	College Admission
# Input marks in Mathematics and Computer Science.

#	Both marks ≥ 50 → "Eligible"
#	Either mark < 50 → "Not Eligible"

# %%
mathematics=int(input("enter marks in mathematics: "))
computer_science=int(input("enter marks in computer science: "))
if mathematics>=50 and computer_science>=50:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# enter marks in mathematics: 78
# enter marks in computer science: 34
# Not Eligible

# %%
#8.	Scholarship Eligibility
# Input percentage and family income.
#	Percentage ≥ 85 and income < ₹3,00,000 → "Full Scholarship"
#	Percentage ≥ 75 and income < ₹5,00,000 → "Partial Scholarship"
#	Otherwise → "Not Eligible"

# %%
percentage=float(input("enter percentage: "))
income=float(input("enter family income: "))
if percentage>=85 and income<300000:
    print("Full Scholarship")
elif percentage>=75 and income<500000:
    print("Partial Scholarship")
else:
    print("Not Eligible")
# Out:
# enter percentage: 65
# enter family income: 6754
# Not Eligible

# %%
#9.	Weekend Activity
# Input day and weather.
#	If day is "Saturday" or "Sunday" → "Weekend"
#	If temperature > 35 → "Stay Indoors"
#	Otherwise → "Normal Day"

# %%
day=input("enter day: ")
weather=int(input("enter weather: "))
if day=="Saturday" or day=="Sunday":
    print("Weekend")
elif weather>35:
    print("Stay Indoors")
else:
    print("Normal Day")
# Out:
# enter day: sunday
# enter weather: 45
# Stay Indoors

# %%
#10.	ATM Security Check
# Input PIN and balance.
#	Correct PIN and balance > 0 → "Account Access Granted"
#	Correct PIN and balance == 0 → "Insufficient Balance"
#	Wrong PIN → "Invalid PIN"

# %%
pin=2009
balance=10000
pin2=int(input("enter pin: "))
if pin2==pin and balance>0:
    print("Account Access Granted")
elif pin2==pin and balance==0:
    print("Insufficient Balance")
else:
    print("Invalid PIN")
# Out:
# enter pin: 2009
# Account Access Granted

# %%
#11.	Job Eligibility
# Input age, qualification, and experience.
#	Age between 21 and 35 and qualification is "Degree" → "Eligible"
#	Age above 35 or experience ≥ 5 years → "Check Senior Position"
#	Otherwise → "Not Eligible"

# %%
age=int(input("enter age: "))
qualification=input("enter qualification: ")
experience=int(input("enter experience: "))
if age>=21 and age<=35 and qualification=="Degree":
    print("Eligible")
elif age>35 or experience>=5:
    print("Check Senior Position")
else:
    print("Not Eligible")
# Out:
# enter age: 65
# enter qualification: mca
# enter experience: 12
# Check Senior Position

# %%
#11.	Student Result
# Input marks in three subjects.

#	If all three marks ≥ 40 → "Pass"
#	If any one mark < 40 → "Supplementary"
#	If two or more marks < 40 → "Fail"
#.	Use: and, or, elif

# %%
mark1=int(input("enter marks in subject 1: "))
mark2=int(input("enter marks in subject 2: "))
mark3=int(input("enter marks in subject 3: "))
if mark1>=40 and mark2>=40 and mark3>=40:
    print("Pass")
elif mark1<40 or mark2<40 or mark3<40:
    print("Supplementary")
else:
    print("Fail")
# Out:
# enter marks in subject 1: 43
# enter marks in subject 2: 64
# enter marks in subject 3: 23
# Supplementary

# %%
#13.	Online Shopping Discount
# Input purchase amount and membership status.
#	Amount ≥ ₹10,000 and member → 20% discount
#	Amount ≥ ₹5,000 or member → 10% discount
#	Otherwise → 5% discount

# %%
purchase_amount=int(input("enter purchase amount: "))
membership_status=input("enter membership status: ")
if purchase_amount>=10000 and membership_status=="member":
    print("20% discount",purchase_amount*0.2)
elif purchase_amount>=5000 or membership_status=="member":
    print("10% discount",purchase_amount*0.1)
else:
    print("5% discount",purchase_amount*0.05)
# Out:
# enter purchase amount: 34000
# enter membership status: member
# 20% discount 6800.0

# %%
#14.	Travel Eligibility
# Input age and health clearance.
#	Age between 18 and 60 and health clearance is "Yes" → "Eligible"
#	Age below 18 or above 60 → "Age Not Eligible"
#	Otherwise → "Medical Clearance Required"

# %%
age=int(input("enter age: "))
health_clearance=input("enter health clearance: ")
if age>=18 and age<=60 and health_clearance=="Yes":
    print("Eligible")
elif age<18 or age>60:
    print("age not eligible")
else:
    print("Medical Clearance Required")
# Out:
# enter age: 34
# enter health clearance: yes
# Medical Clearance Required

# %%
#15.	Hostel Admission
# Input distance from college, family income, and student status.
#	Distance > 50 km and student is "Yes" → "Hostel Priority"
#	Income < ₹2,00,000 or distance > 30 km → "Hostel Consideration"
#	Otherwise → "Not Eligible"

# %%
collage_distance=int(input("enter distance from college: "))
family_income=int(input("enter family income: "))
student_status=input("enter student status: ")
if collage_distance>50 and student_status=="Yes":
    print("Hostel Priority")
elif family_income<200000 or collage_distance>30:
    print("Hostel Consideration")
else:
    print("Not Eligible")
# Out:
# enter distance from college: 45
# enter family income: 56000
# enter student status: yes
# Hostel Consideration

# %%
#16.	Bank Loan Eligibility
# Input salary, credit score, and employment status.
#	Salary ≥ ₹50,000 and credit score ≥ 750 → "Loan Approved"
#	Salary ≥ ₹30,000 or credit score ≥ 700 → "Further Verification"
#	Otherwise → "Loan Rejected"

# %%
salary=int(input("enter salary: "))
credit_score=int(input("enter credit score: "))
employment_status=input("enter employment status: ")
if salary>=50000 and credit_score>=750:
    print("Loan Approved")
elif salary>=30000 or credit_score>=700:
    print("Further Verification")
else:
    print("Loan Rejected")
# Out:
# enter salary: 30000
# enter credit score: 700
# enter employment status: yes
# Further Verification

# %%
#17.	 College Placement Eligibility
#Input:
#	CGPA
#	Backlogs
#	Internship status
#Rules:
#	CGPA ≥ 8 and backlogs == 0 and internship == "Yes" → "Eligible for Premium Companies"
#	CGPA ≥ 7 and backlogs <= 1 → "Eligible for Regular Companies"
#	CGPA < 7 or backlogs > 1 → "Not Eligible"

# %%
CGPA=float(input("enter CGPA: "))
backlogs=int(input("enter backlogs: "))
internship_status=input("enter internship status: ")
if CGPA>=8 and backlogs==0 and internship_status=="Yes":
    print("Eligible for Premium Companies")
elif CGPA>=7 and backlogs<=1:
    print("Eligible for Regular Companies")
else:
    print("Not Eligible")
# Out:
# enter CGPA: 6
# enter backlogs: 0
# enter internship status: yes
# Not Eligible

# %%
#      18. Airport Security Check
#Input passenger age, ticket status, and valid ID.
#	Age ≥ 18 and ticket == "Yes" and ID == "Yes" → "Boarding Allowed"
#	Ticket == "No" or ID == "No" → "Boarding Not Allowed"
#	Otherwise → "Additional Verification"

# %%
passenger_age=int(input("enter passenger age: "))
ticket_status=input("enter ticket status: ")
valid_ID=input("enter valid ID: ")
if passenger_age>=18 and ticket_status=="Yes" and valid_ID=="Yes":
    print("Boarding Allowed")
elif ticket_status=="No" or valid_ID=="No":
    print("Boarding Not Allowed")
else:
    print("Additional Verification")
# Out:
# enter passenger age: 19
# enter ticket status: yes
# enter valid ID: yes
# Additional Verification

# %%
#18.	Electricity Usage Alert
#Input units consumed.
#	Units > 500 → "Very High Usage"
#	Units between 300 and 500 → "High Usage"
#	Units between 100 and 299 → "Moderate Usage"
#	Otherwise → "Low Usage"
#Add another condition:
#	If units > 500 or units < 0 → "Invalid/Check Meter Reading"

# %%
units_consumed=int(input("enter units consumed: "))
if units_consumed>500:
    print("Very High Usage")
elif units_consumed>=300 and units_consumed<=500:
    print("High Usage")
elif units_consumed>=100 and units_consumed<=299:
    print("Moderate Usage")
else:
    print("Low Usage")
if units_consumed>500 or units_consumed<0:
    print("Invalid/Check Meter Reading")
# Out:
# enter units consumed: 340
# High Usage

# %%
#19.	E-Commerce Delivery
#Input order amount, distance, and membership.
#	Amount ≥ ₹5,000 and distance ≤ 10 km → "Free Delivery"
#	Amount ≥ ₹2,000 or membership == "Premium" → "Reduced Delivery Charge"
#	Otherwise → "Standard Delivery Charge"

# %%
order_amount=int(input("enter order amount: "))
distance=int(input("enter distance: "))
membership=input("enter membership: ")
if order_amount>=5000 and distance<=10:
    print("Free Delivery")
elif order_amount>=2000 or membership=="Premium":
    print("Reduced Delivery Charge")
else:
    print("Standard Delivery Charge")
# Out:
# enter order amount: 4000
# enter distance: 30
# enter membership: premium
# Reduced Delivery Charge

# %%
#20.	Smart Classroom Access
#A student can enter a computer lab if:
#	Attendance ≥ 75 and ID card is available
#	or
#	The student has special permission.
#Display:
#	"Lab Access Granted"
#	"Permission Required"
#	"Access Denied"

# %%
attendence_percentage=int(input("enter attendence percentage: "))
id_card=input("enter id card availability: ")
special_permission=input("enter special permission: ")
if attendence_percentage>=75 and id_card=="Yes":
    print("Lab Access Granted")
elif special_permission=="Yes":
    print("Permission Required")
else:
    print("Access Denied")
# Out:
# enter attendence percentage: 243
# enter id card availability: yes
# enter special permission: yes
# Access Denied
